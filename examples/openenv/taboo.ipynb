# %% [markdown]
# This notebook demonstrates how to use the clemcore OpenEnv integration to run a
# multi-player game with the game **"Taboo"**, and how to plug in a self-hosted
# OpenAI-compatible model server as an agent backend.
#
# You will learn how to:
#
# 1. Set up the environment and install dependencies.
# 2. Register and configure a model as an agent backend.
# 3. Implement a simple custom describer agent.
# 4. Run an automated gameplay session and inspect the interactions.
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](
# https://colab.research.google.com/phisad/playpen/blob/main/examples/openenv/taboo.ipynb
# )

# %% [markdown]
# # 1. Environment setup and dependency installation
#
# ## 1.1. Setup environment
#
# We start by specifying:
#
# - The game name (here we use `"taboo"`, but this pattern works for any 2‑player game).
# - `CLEMBENCH_HOME`, the local path where the `clembench` repository is located.
#   This environment variable is used by the CLI and Python APIs to locate games.

# %%
import os

# Specify the game name here (this code can be adapted to any 2-player game)
GAME_NAME = "taboo"

# Local clone location of the clembench repository
CLEMBENCH_HOME = os.path.expanduser("~/git/clembench")

# Expose CLEMBENCH_HOME so the clem framework can find the games
os.environ["CLEMBENCH_HOME"] = CLEMBENCH_HOME

# %% [markdown]
# ## 1.2. Install games and dependencies
#
# In this step we:
#
# 1. Clone the `clembench` repository (skip if you already have it).
# 2. Install its Python dependencies into the current Jupyter kernel.
# 3. Verify that `clembench` is installed and that the `taboo` game is visible.
#
# You should:
#
# - See a valid version printed by `clem --version`.
# - See `taboo` listed by `clem list games -s taboo`.
#
# If you do **not** see `taboo`, double‑check `CLEMBENCH_HOME` and that the clone succeeded.

# %%
# Clone the clembench repo (safe to re-run; git will warn if it already exists)
# !git clone https://github.com/clp-research/clembench $CLEMBENCH_HOME

# Install the requirements into the Python kernel
# %pip install -r $CLEMBENCH_HOME/requirements.txt

# Make tqdm usable in Jupyter notebooks
# %pip install --upgrade ipywidgets jupyter_client
# Out:
# fatal: destination path '/Users/philippsadler/git/clembench' already exists and is not an empty directory.
# Requirement already satisfied: clemcore<4.0.0,>=3.3.5 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (3.3.5)
# Requirement already satisfied: datasets~=3.5.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (3.5.1)
# Requirement already satisfied: jinja2~=3.1.6 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: langdetect~=1.0.9 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 4)) (1.0.9)
# Requirement already satisfied: immutabledict~=4.2.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 5)) (4.2.1)
# Requirement already satisfied: lark==1.1.9 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 6)) (1.1.9)
# Requirement already satisfied: clingo==5.7.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 7)) (5.7.1)
# Requirement already satisfied: spacy==3.7.4 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (3.7.4)
# Requirement already satisfied: nltk==3.8.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 10)) (3.8.1)
# Requirement already satisfied: scikit-learn in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 11)) (1.7.0)
# Requirement already satisfied: matplotlib in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 12)) (3.7.1)
# Requirement already satisfied: networkx in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 13)) (3.4.2)
# Requirement already satisfied: imageio in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 14)) (2.37.0)
# Requirement already satisfied: numpy in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 15)) (1.26.4)
# Requirement already satisfied: Levenshtein in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 16)) (0.27.1)
# Requirement already satisfied: kaggle in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 17)) (1.7.4.5)
# Requirement already satisfied: gymnasium in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 18)) (1.1.1)
# Requirement already satisfied: pygame in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from -r /Users/philippsadler/git/clembench/requirements.txt (line 19)) (2.6.1)
# Requirement already satisfied: cffi in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clingo==5.7.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 7)) (1.17.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (1.0.13)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (3.0.10)
# Requirement already satisfied: thinc<8.3.0,>=8.2.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (8.2.5)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (0.9.4)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (2.11.4)
# Requirement already satisfied: setuptools in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (44.1.1)
# Requirement already satisfied: packaging>=20.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (25.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (3.5.0)
# Requirement already satisfied: click in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from nltk==3.8.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 10)) (8.1.8)
# Requirement already satisfied: joblib in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from nltk==3.8.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 10)) (1.5.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from nltk==3.8.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 10)) (2024.11.6)
# Requirement already satisfied: pyyaml>=6.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (6.0.2)
# Requirement already satisfied: retry>=0.9.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.9.2)
# Requirement already satisfied: openai==1.99.9 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.99.9)
# Requirement already satisfied: anthropic==0.64.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.64.0)
# Requirement already satisfied: cohere==5.17 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (5.17.0)
# Requirement already satisfied: google-generativeai==0.8.5 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.8.5)
# Requirement already satisfied: mistralai==1.9.6 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.9.6)
# Requirement already satisfied: pandas==2.0.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: seaborn==0.12.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.12.2)
# Requirement already satisfied: sparklines~=0.7.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: pylatex~=1.4.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.4.2)
# Requirement already satisfied: ordered-set~=4.1.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: markdown~=3.8.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (3.8.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from matplotlib->-r /Users/philippsadler/git/clembench/requirements.txt (line 12)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from matplotlib->-r /Users/philippsadler/git/clembench/requirements.txt (line 12)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from matplotlib->-r /Users/philippsadler/git/clembench/requirements.txt (line 12)) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from matplotlib->-r /Users/philippsadler/git/clembench/requirements.txt (line 12)) (1.4.8)
# Requirement already satisfied: pillow>=6.2.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from matplotlib->-r /Users/philippsadler/git/clembench/requirements.txt (line 12)) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from matplotlib->-r /Users/philippsadler/git/clembench/requirements.txt (line 12)) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from matplotlib->-r /Users/philippsadler/git/clembench/requirements.txt (line 12)) (2.9.0.post0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from anthropic==0.64.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (4.9.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from anthropic==0.64.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.25.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from anthropic==0.64.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from anthropic==0.64.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.9.0)
# Requirement already satisfied: sniffio in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from anthropic==0.64.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from anthropic==0.64.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (4.13.2)
# Requirement already satisfied: fastavro<2.0.0,>=1.9.4 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from cohere==5.17->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.10.0)
# Requirement already satisfied: httpx-sse==0.4.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from cohere==5.17->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: pydantic-core<3.0.0,>=2.18.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from cohere==5.17->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (2.33.2)
# Requirement already satisfied: tokenizers<1,>=0.15 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from cohere==5.17->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.21.1)
# Requirement already satisfied: types-requests<3.0.0,>=2.0.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from cohere==5.17->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (2.32.4.20250913)
# Requirement already satisfied: google-ai-generativelanguage==0.6.15 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.6.15)
# Requirement already satisfied: google-api-core in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (2.24.2)
# Requirement already satisfied: google-api-python-client in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (2.169.0)
# Requirement already satisfied: google-auth>=2.15.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (2.39.0)
# Requirement already satisfied: protobuf in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (5.29.4)
# Requirement already satisfied: eval-type-backport>=0.2.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from mistralai==1.9.6->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: invoke<3.0.0,>=2.2.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from mistralai==1.9.6->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (2.2.1)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from mistralai==1.9.6->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.4.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from pandas==2.0.1->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from pandas==2.0.1->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.3 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-ai-generativelanguage==0.6.15->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.26.1)
# Requirement already satisfied: filelock in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (3.18.0)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (20.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (0.3.8)
# Requirement already satisfied: xxhash in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (2025.3.0)
# Requirement already satisfied: aiohttp in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (3.11.18)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (0.30.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from jinja2~=3.1.6->-r /Users/philippsadler/git/clembench/requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: six in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from langdetect~=1.0.9->-r /Users/philippsadler/git/clembench/requirements.txt (line 4)) (1.17.0)
# Requirement already satisfied: scipy>=1.8.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from scikit-learn->-r /Users/philippsadler/git/clembench/requirements.txt (line 11)) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from scikit-learn->-r /Users/philippsadler/git/clembench/requirements.txt (line 11)) (3.6.0)
# Requirement already satisfied: rapidfuzz<4.0.0,>=3.9.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from Levenshtein->-r /Users/philippsadler/git/clembench/requirements.txt (line 16)) (3.13.0)
# Requirement already satisfied: bleach in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from kaggle->-r /Users/philippsadler/git/clembench/requirements.txt (line 17)) (6.2.0)
# Requirement already satisfied: certifi>=14.05.14 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from kaggle->-r /Users/philippsadler/git/clembench/requirements.txt (line 17)) (2025.4.26)
# Requirement already satisfied: charset-normalizer in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from kaggle->-r /Users/philippsadler/git/clembench/requirements.txt (line 17)) (3.4.2)
# Requirement already satisfied: idna in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from kaggle->-r /Users/philippsadler/git/clembench/requirements.txt (line 17)) (3.10)
# Requirement already satisfied: python-slugify in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from kaggle->-r /Users/philippsadler/git/clembench/requirements.txt (line 17)) (8.0.4)
# Requirement already satisfied: text-unidecode in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from kaggle->-r /Users/philippsadler/git/clembench/requirements.txt (line 17)) (1.3)
# Requirement already satisfied: urllib3>=1.15.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from kaggle->-r /Users/philippsadler/git/clembench/requirements.txt (line 17)) (2.4.0)
# Requirement already satisfied: webencodings in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from kaggle->-r /Users/philippsadler/git/clembench/requirements.txt (line 17)) (0.5.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from gymnasium->-r /Users/philippsadler/git/clembench/requirements.txt (line 18)) (3.1.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from gymnasium->-r /Users/philippsadler/git/clembench/requirements.txt (line 18)) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from aiohttp->datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from aiohttp->datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (1.3.2)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from aiohttp->datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from aiohttp->datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from aiohttp->datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from aiohttp->datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from aiohttp->datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from aiohttp->datasets~=3.5.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 2)) (1.20.0)
# Requirement already satisfied: language-data>=1.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from langcodes<4.0.0,>=3.2.0->spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (0.7.0)
# Requirement already satisfied: decorator>=3.4.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from retry>=0.9.2->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (5.2.1)
# Requirement already satisfied: py<2.0.0,>=1.4.26 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from retry>=0.9.2->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.11.0)
# Requirement already satisfied: termcolor>=2.4.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from sparklines~=0.7.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (3.1.0)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from thinc<8.3.0,>=8.2.2->spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (0.1.5)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from weasel<0.4.0,>=0.1.0->spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (0.16.0)
# Requirement already satisfied: pycparser in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from cffi->clingo==5.7.1->-r /Users/philippsadler/git/clembench/requirements.txt (line 7)) (2.22)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from anyio<5,>=3.5.0->anthropic==0.64.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.2.2)
# Requirement already satisfied: googleapis-common-protos<2.0.0,>=1.56.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-api-core->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.70.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-auth>=2.15.0->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (4.9.1)
# Requirement already satisfied: httpcore==1.* in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from httpx<1,>=0.25.0->anthropic==0.64.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.25.0->anthropic==0.64.0->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.16.0)
# Requirement already satisfied: marisa-trie>=1.1.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy==3.7.4->-r /Users/philippsadler/git/clembench/requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: httplib2<1.0.0,>=0.19.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-api-python-client->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.22.0)
# Requirement already satisfied: google-auth-httplib2<1.0.0,>=0.2.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-api-python-client->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: uritemplate<5,>=3.0.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-api-python-client->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (4.1.1)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.71.0)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.10.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,!=2.8.*,!=2.9.*,<3.0.0dev,>=1.34.1->google-ai-generativelanguage==0.6.15->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (1.71.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=2.15.0->google-generativeai==0.8.5->clemcore<4.0.0,>=3.3.5->-r /Users/philippsadler/git/clembench/requirements.txt (line 1)) (0.6.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: ipywidgets in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (8.1.8)
# Requirement already satisfied: jupyter_client in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (8.7.0)
# Requirement already satisfied: comm>=0.1.3 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipywidgets) (8.37.0)
# Requirement already satisfied: traitlets>=4.3.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: jupyter-core>=5.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from jupyter_client) (5.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from jupyter_client) (2.9.0.post0)
# Requirement already satisfied: pyzmq>=25.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from jupyter_client) (27.1.0)
# Requirement already satisfied: tornado>=6.4.1 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from jupyter_client) (6.5.4)
# Requirement already satisfied: decorator in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: exceptiongroup in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (1.2.2)
# Requirement already satisfied: jedi>=0.16 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (2.19.1)
# Requirement already satisfied: stack_data in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from ipython>=6.1.0->ipywidgets) (4.13.2)
# Requirement already satisfied: platformdirs>=2.5 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from jupyter-core>=5.1->jupyter_client) (4.5.1)
# Requirement already satisfied: six>=1.5 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->jupyter_client) (1.17.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.2.14)
# Requirement already satisfied: executing>=1.2.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages (from stack_data->ipython>=6.1.0->ipywidgets) (0.2.3)
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Sanity check: version + confirm that the game is an available game
# !clem --version
# !clem list games -s $GAME_NAME
# Out:
# clem 3.3.5
# Listing all available games (use -v option to see the whole specs)
# Found '1' game specs that match the game_selector='{'game_name': 'taboo'}'
# taboo:
#  	Taboo game between two agents where one has to describe a word for
# 	the other to guess.

# %% [markdown]
# # 2. Register and configure a model backend
#
# We will use a self-hosted OpenAI-compatible model server and register the model
# under the name `"clp-chat"`.
#
# This name (`"clp-chat"`) will later be used when we assign the model to a player
# in the Gymnasium environment.

# %%
# Register the remote model under the name "clp-chat"
# !clem register model -n "clp-chat" -v "backend=openai_compatible,model_id=Qwen/Qwen3-VL-30B-A3B-Thinking-FP8" --cwd
# Out:
# Updated model registry at /Users/philippsadler/Opts/Git/playpen/examples/openenv/model_registry.json successfully: {"model_name":"clp-chat","backend":"openai_compatible","lookup_source":"/Users/philippsadler/Opts/Git/playpen/examples/openenv/model_registry.json","model_id":"Qwen/Qwen3-VL-30B-A3B-Thinking-FP8"}

# %% [markdown]
# You can achieve the same registration programmatically if you prefer not to use
# the CLI:

# %%
from clemcore.backends import ModelRegistry

registry = ModelRegistry.register("clp-chat", backend="openai_compatible",
                                  model_id="Qwen/Qwen3-VL-30B-A3B-Thinking-FP8")
registry.get_first_model_spec_that_unify_with("clp-chat")
# Out:
# ModelSpec({'model_name': 'clp-chat', 'backend': 'openai_compatible', 'lookup_source': '/Users/philippsadler/Opts/Git/playpen/examples/openenv/model_registry.json', 'model_id': 'Qwen/Qwen3-VL-30B-A3B-Thinking-FP8'})

# %% [markdown]
# ## 2.2. Register API key and base URL
#
# To connect to your OpenAI-compatible model server, we also register:
#
# - An API key
# - An organisation (if applicable)
# - A base URL for the endpoint
#
# Replace the placeholders with your actual values.

# %%
API_KEY = "<insert-api-key-here>"
ORGANIZATION = "<insert-organisation-here>"
BASE_URL = "<insert-base-url-here>"

# %%
# Register the credentials and base URL for the "openai_compatible" backend
# !clem register key -n "openai_compatible" -v "api_key=$API_KEY,organisation=$ORGANIZATION,base_url=$BASE_URL" --cwd

# %% [markdown]
# Programmatic equivalent:

# %%
from clemcore.backends import KeyRegistry

KeyRegistry.register("openai_compatible", api_key=API_KEY, organisation=ORGANIZATION, base_url=BASE_URL, force_cwd=True)

# %% [markdown]
# # 3. Implement a custom describer agent
#
# Next, we implement a simple custom describer agent by subclassing `ClemAgent`.
# The agent:
#
# - Uses the `"clp-chat"` model backend.
# - Generates a guess based on the full interaction history in the Taboo game.
#
# This is just a toy example to show how you can plug in your own logic.

# %%
from playpen.agents import ClemAgent, ClemObservation
from clemcore.backends import load_model


class MyAgenticDescriber(ClemAgent):
    """
    Simple example agent for Taboo.

    It calls the "clp-chat" model with the current interaction history and
    uses the model's response as the next guess.
    """

    def __init__(self):
        super().__init__()
        # with a reasoning model we must allow more tokens to account for the thinking process
        self.model = load_model("clp-chat", gen_args=dict(temperature=0.7, max_tokens=None))

    def act(self, last: ClemObservation) -> str:
        # Use the full history (which usually already includes the last observation)
        _, _, response_text = self.model.generate_response(self.history)
        # Observe our own response in the interaction history
        self.observe(dict(role="user", content=response_text))
        return response_text


describer = MyAgenticDescriber()
# Out:
# .--------------..--------------..--------------..--------------..--------------..--------------..--------------.
# |   ______     ||   _____      ||      __      ||  ____  ____  ||   ______     ||  _________   || ____  _____  |
# |  |_   __ \   ||  |_   _|     ||     /  \     || |_  _||_  _| ||  |_   __ \   || |_   ___  |  |||_   \|_   _| |
# |    | |__) |  ||    | |       ||    / /\ \    ||   \ \  / /   ||    | |__) |  ||   | |_  \_|  ||  |   \ | |   |
# |    |  ___/   ||    | |   _   ||   / ____ \   ||    \ \/ /    ||    |  ___/   ||   |  _|  _   ||  | |\ \| |   |
# |   _| |_      ||   _| |__/ |  || _/ /    \ \_ ||    _|  |_    ||   _| |_      ||  _| |___/ |  || _| |_\   |_  |
# |  |_____|     ||  |________|  |||____|  |____|||   |______|   ||  |_____|     || |_________|  |||_____|\____| |
# '--------------''--------------''--------------''--------------''--------------''--------------''--------------'
#
# 2026-01-09 15:40:42,326 - clemcore.backends - INFO - Found registered model spec that unifies with {"model_name":"clp-chat"} -> {'model_name': 'clp-chat', 'backend': 'openai_compatible', 'lookup_source': '/Users/philippsadler/Opts/Git/playpen/examples/openenv/model_registry.json', 'model_id': 'Qwen/Qwen3-VL-30B-A3B-Thinking-FP8'}
# 2026-01-09 15:40:42,328 - clemcore.backends - INFO - Found registry entry for backend openai_compatible -> {'backend': 'openai_compatible', 'file_name': 'openai_compatible_api.py', 'file_path': '/Users/philippsadler/Opts/Git/playpen/venv/lib/python3.10/site-packages/clemcore/backends/openai_compatible_api.py', 'lookup_source': 'packaged'}
# 2026-01-09 15:40:42,329 - clemcore.backends - INFO - Dynamically import backend openai_compatible
# 2026-01-09 15:40:43,475 - clemcore.backends - INFO - Successfully loaded clp-chat model
# 2026-01-09 15:40:43,477 - clemcore.backends - INFO - Loading models took: 0:00:01.148052

# %% [markdown]
# # 4. Run an automated gameplay session
#
# We now:
#
# 1. Set up an OpenEnv environment for the game where we use the registered `"clp-chat"` model to play `player_1` as part of the environment.
# 2. Run through a single episode and log the interaction at each step where we use our custom describer to play `player_0` as the learning agent.
#
# Note that:
# - Setting `--single_pass` allows to iterate through all game instances only once times, e.g., for evaluation.
# - You can also restrict which instances are used via the `--split [train,validation]` option.

# %% [markdown]
# ## 4.1. Starting the server and connecting the client
#
# Open a terminal in the notebook folder and run the `clem serve` command to start the OpenEnv environment:
#
# ```bash
# clem serve --game taboo --learner-agent player_0 --env-agents "player_1=clp-chat"
# ```
#
# The output should look similar to:
# ```
# INFO:     Started server process [73210]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# ```
#
# From this log you obtain the host and port (here `http://0.0.0.0:8000`) that the client should connect to.

# %%
from clemcore.clemgame import ClemGameEnv

game_env = ClemGameEnv(base_url="http://0.0.0.0:8000")

# %% [markdown]
# ## 4.2. Run through an episode and log the interaction

# %%
from playpen.agents.openenv import ClemGameEnvAgent

# Wrap the agent in a ClemGameEnvAgent to use it with the OpenEnv client
openenv_describer = ClemGameEnvAgent(describer)

last_obs = game_env.reset()
context_response_pairs: list[tuple] = []
counter = 0
while not last_obs.done:
    print(f"Round: {counter} ...")
    action = openenv_describer(last_obs)  # this is a StepResult[ClemGameObservation]
    obs = game_env.step(action)
    context_response_pairs.append((last_obs.observation, action.response, last_obs.reward or 0.))
    last_obs = obs
    counter += 1

# Reset agent state between episodes (if it maintains any internal memory)
openenv_describer.reset()

print(f"Episode took these {len(context_response_pairs)} steps:")
print("-" * 20)
for idx, (context, response, reward) in enumerate(context_response_pairs):
    print(f"Step {idx} / Reward {reward:.2f}:")
    print(f"Describer <- Context:", context)
    print(f"Describer -> Response:", response)
    print("-" * 20)

print("Final reward:", reward)
# Out:
# Round: 0 ...
# Episode took these 1 steps:
# --------------------
# Step 0 / Reward 0.00:
# Describer <- Context: ClemGameObservation(done=False, reward=None, metadata={}, context={'role': 'user', 'content': 'You are playing a collaborative word guessing game in which you have to describe a target word for another player to guess.\n\nRules:\n(a) You have to reply in the form: CLUE: <some text>. Guesses from the other player will start with GUESS.\n(b) You cannot use the target word itself, parts or morphological variants of it in your description.\n(c) In addition, the same rules apply for related words which are provided below.\n\nEnd conditions:\n(i) If you use the target word or a related word in your description, then you lose.\n(ii) If the other player can guess the target word in 3 tries, you both win.\n\nLet us start.\n\nThis is the target word that you need to describe and that the other player needs to guess:\n\nfort\n\nRelated words are:\n\n- meet\n- garrison\n- fortify\n\nImportant: You are under time pressure, give short descriptions that are to the point!'})
# Describer -> Response: ClemGameAction(metadata={}, response='CLUE: military outpost')
# --------------------
# Final reward: 0.0
